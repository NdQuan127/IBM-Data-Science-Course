# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook provides an overview of key data science languages, libraries, tools, and some basic arithmetic operations.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Category | Tools |
# |----------|-------|
# | Data Management | MySQL, PostgreSQL, Apache Cassandra, Elasticsearch, Ceph, CouchDB, MongoDB, Hadoop HDFS |
# | Operating Systems | Jupyter IDE, RStudio, Microsoft Visual Studio, PyCharm, Spyder, Anaconda Navigator |
# | Data Integration & Transformation | Apache Spark SQL, Kubeflow, Node-RED, Apache Airflow, Apache NiFi, Apache Kafka |
# | Data Visualization | PixieDust, Kibana, Hue, Apache Superset |
# | Model Deployment | Apache PredictionIO, Kubernetes, MLeap, TensorFlow Lite, Apache Seldon, Red Hat OpenShift, TensorFlow Serving, TensorFlow.js |
# | Model Monitoring & Assessment | IBM AI Fairness 360, IBM AI Explainability 360, IBM Adversarial Robustness 360 Toolbox, Prometheus, ModelDB |
# | Code Asset Management | Git, GitLab, GitHub, Bitbucket |
# | Data Asset Management | ODPi Egeria, Kylo, Apache Atlas |

# %% [markdown]
# ## Below are a few examples of evaluating arithmetic expressions in Python

# %%
# Multiply and add numbers
(3 * 4) + 5
# Out:
# 17

# %%
# Convert minutes to hours
120 / 60
# Out:
# 2.0

# %% [markdown]
# ## Objectives
# - List popular data science languages
# - Identify commonly used data science libraries
# - Introduce key data science tools
# - Demonstrate basic arithmetic operations in Python
# - Show how to convert minutes to hours using Python

# %% [markdown]
# ## Author
# Nguyen Duc Quan
